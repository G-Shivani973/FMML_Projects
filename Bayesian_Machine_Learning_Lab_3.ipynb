# %% [markdown]
# <a href="https://colab.research.google.com/github/G-Shivani973/FMML_Projects/blob/main/Bayesian_Machine_Learning_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bayesian Machine Learning: Lab 3

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-03 17:02:36--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  76.9MB/s    in 0.9s
#
# 2024-04-03 17:02:37 (76.9 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 21505   0802.2906v2  Dimensionality reduction is a topic of recent ...  stat
# 30507  1712.03866v1  We present a method for the real-time estimati...    cs
# 33065  1802.00174v2  The linear model uses the space defined by the...    cs
# 7974   1705.07878v6  High network communication cost for synchroniz...    cs
# 5721    1202.5514v2  This paper deals with the binary classificatio...  stat
# ...             ...                                                ...   ...
# 21632   1204.4708v1  We present an new sequential Monte Carlo sampl...  stat
# 21107  1707.09704v1  I propose the purpose our concept of actual ca...    cs
# 1631   1702.07983v1  Despite the successes in capturing continuous ...    cs
# 22843  1708.06935v1  We present a novel approach for estimating con...  stat
# 22266  1511.01284v1  In life sciences, the experts generally use em...  stat
#
#                                                    title  year  \
# 21505  Classification Constrained Dimensionality Redu...  2008
# 30507  Using a single RGB frame for real time 3D hand...  2017
# 33065                       Augmented Space Linear Model  2018
# 7974   TernGrad: Ternary Gradients to Reduce Communic...  2017
# 5721   Classification approach based on association r...  2012
# ...                                                  ...   ...
# 21632  Efficient hierarchical clustering for continuo...  2012
# 21107                          Cost and Actual Causation  2017
# 1631   Maximum-Likelihood Augmented Discrete Generati...  2017
# 22843  Hierarchical Multinomial-Dirichlet model for t...  2017
# 22266  Lasso based feature selection for malaria risk...  2015
#
#                                                 keywords
# 21505  [dimensionality, reduction, classification, co...
# 30507  [estimation, commodity, displayed, impressive,...
# 33065  [parameters, nonlinear, nonlinear, performance...
# 7974   [communication, synchronizing, gradients, para...
# 5721   [classification, probability, occurrence, situ...
# ...                                                  ...
# 21632  [sequential, coalescent, hierarchical, cluster...
# 21107  [causation, minimizing, intervention, causatio...
# 1631   [successes, capturing, continuous, distributio...
# 22843  [estimating, conditional, probability, indepen...
# 22266  [generally, empirical, knowledge, variables, i...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 21505    [dimensionality, reduction, classification, co...
# 30507    [estimation, commodity, displayed, impressive,...
# 33065    [parameters, nonlinear, nonlinear, performance...
# 7974     [communication, synchronizing, gradients, para...
# 5721     [classification, probability, occurrence, situ...
#                                ...
# 7385     [convolutional, important, successful, classif...
# 33197    [embeddings, immensely, representation, intera...
# 667      [mirroring, architecture, dimensionality, redu...
# 13457    [classification, activities, frequency, compon...
# 31971    [desirable, parameters, asymptotically, perfor...
# Name: keywords, Length: 6000, dtype: object

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8846 words.
# Out of those 4574 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9e93e043-82f4-4af4-822c-bfbf730a12bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e93e043-82f4-4af4-822c-bfbf730a12bb")) {                    Plotly.newPlot(                        "9e93e043-82f4-4af4-822c-bfbf730a12bb",                        [{"x":["demonstrate","extension","supervised","constrained","embedding","dimension","introduce","dimensionality","connection","estimation","information","reduction","performance","classifiers","neighbors","intrinsic","classifier","expressions","algorithm","investigate","improvement","satellite","preprocessing","classification","unlabeled","scenarios","techniques","impressive","recovering","extensive","qualitative","unrestricted","pretrained","minimization","positions","advancements","commodity","monocular","estimated","assessment","comparison","generative","calibration","combining","experimental","specifically","displayed","introduction","capitalize","computational","advantage","cumbersome","complexity","augmented","approaches","neighborhood","projection","efficiency","nonlinear","parameters","accelerate","aggressively","bottleneck","communication","assumption","numerical","experiments","convergence","scalability","distributed","gradients","mathematically","googlenet","significant","parallelism","available","situation","probability","expresses","unbalanced","variables","identification","unsupervised","sensibility","association","considering","regression","occurrence","discovery","correlated","discriminant","relationships","assumptions","calculation","inference","remaining","distributions","factorial","political","typically","independence","preferences","probabilistic","processing","particularly","factorizations","principle","preference","smoothness","elections","literature","underlying","predominantly","efficient","structural","accompanied","selection","population","objectives","solutions","discovering","composite","consistently","candidates","tradeoffs","promising","optimization","important","deceptive","mechanism","compensate","particular","combinations","maintains","diversity","transformation","therefore","objective","environment","simultaneously","exploitation","challenging","guarantee","everybody","internally","practically","illustrate","achieving","impossible","protected","contradicting","inferring","similarly","undesired","enforcement","accumulation","additional","diagnosis","hospitals","confronted","challenge","framework","unrelated","virtually","universally","adversarial","automatically","companies","corresponds","generalize","transition","generalizing","unprecedented","applicable","spontaneously","robustness","similarities","parameter","spontaneous","understand","lagrangian","experimentally","correlations","decoupling","explosion","symmetries","described","lipschitz","incidentally","empirically","predictions","orthogonal","efficiently","theoretically","motivated","perturbation","extensions","improving","counterpart","maintained"],"y":[595,87,177,56,102,68,334,52,45,201,714,95,899,103,20,38,131,34,800,132,147,11,17,511,43,102,408,16,21,175,51,6,12,70,25,13,4,14,58,42,149,129,14,106,390,150,11,20,3,273,92,5,274,48,434,20,46,164,56,256,24,2,25,68,75,78,626,107,28,100,38,13,4,244,12,297,35,150,2,3,139,101,139,1,28,73,124,32,52,32,18,66,76,17,203,26,108,6,9,111,37,41,155,270,88,4,55,32,15,5,144,130,3,404,74,3,137,40,30,147,29,13,46,23,9,125,308,363,5,112,13,293,43,14,35,50,149,154,126,114,14,265,30,1,1,8,73,76,15,4,1,28,20,5,8,6,116,52,5,0,156,566,1,7,3,108,180,6,31,48,42,17,11,49,1,94,34,112,9,78,6,47,27,6,6,9,80,5,0,65,78,18,153,33,69,13,40,96,13,6],"type":"bar"},{"x":["demonstrate","extension","supervised","constrained","embedding","dimension","introduce","dimensiona ...

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4574,), (4574, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.795

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>3D</span> <span style=''>DETNet</span> <span style=''>a</span> <span style=''>Single</span> <span style=''>Stage</span> <span style=''>Video</span> <span style=''>Based</span> <span style=''>Vehicle</span> <span style=''>Detector</span> <br/><br/><span style=''>Video</span> <span style=''>based</span> <span style=''>vehicle</span> <span style='background-color:rgba(0, 255, 0, 0.5374449339207049);'>detection</span> <span style=''>has</span> <span style=''>received</span> <span style='background-color:rgba(0, 255, 0, 0.4000000000000001);'>considerable</span> <span style='background-color:rgba(0, 255, 0, 0.3568627450980393);'>attention</span> <span style=''>over</span> <span style=''>the</span> <span style=''>last</span> <span style=''>ten</span> <span style=''>years</span> <span style=''>and</span> <span style=''>there</span> <span style=''>are</span> <span style=''>many</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.5374449339207049);'>detection</span> <span style=''>methods</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>it</span> <span style=''>However</span> <span style=''>these</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>devised</span> <span style=''>for</span> <span style=''>still</span> <span style=''>images</span> <span style=''>and</span> <span style=''>applying</span> <span style=''>them</span> <span style=''>for</span> <span style=''>video</span> <span style=''>vehicle</span> <span style='background-color:rgba(0, 255, 0, 0.5374449339207049);'>detection</span> <span style=''>directly</span> <span style=''>always</span> <span style=''>obtains</span> <span style=''>poor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>single</span> <span style=''>stage</span> <span style=''>video</span> <span style=''>based</span> <span style=''>vehicle</span> <span style=''>detector</span> <span style='background-color:rgba(0, 255, 0, 0.441860465116279);'>integrated</span> <span style=''>with</span> <span style=''>3DCovNet</span> <span style=''>and</span> <span style=''>focal</span> <span style=''>loss</span> <span style=''>called</span> <span style=''>3D</span> <span style=''>DETNet</span> <span style=''>Draw</span> <span style=''>support</span> <span style=''>from</span> <span style=''>3D</span> <span style='background-color:rgba(0, 255, 0, 0.6923076923076923);'>Convolution</span> <span style=''>network</span> <span style=''>and</span> <span style=''>focal</span> <span style=''>loss</span> <span style=''>our</span> <span style=''>method</span> <span style=''>has</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>capture</span> <span style=''>motion</span> <span style='background-color:rgba(0, 255, 0, 0.3100917431192661);'>information</span> <span style=''>and</span> <span style=''>is</span> <span style=''>more</span> <span style=''>suitable</span> <span style=''>to</span> <span style=''>detect</span> <span style=''>vehicle</span> <span style=''>in</span> <span style=''>video</span> <span style=''>than</span> <span style=''>other</span> <span style=''>single</span> <span style=''>stage</span> <span style=''>methods</span> <span style=''>devised</span> <span style=''>for</span> <span style=''>static</span> <span style=''>images</span> <span style=''>The</span> <span style=''>multiple</span> <span style=''>video</span> <span style=''>frames</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>initially</span> <span style=''>fed</span> <span style=''>to</span> <span style=''>3D</span> <span style=''>DETNet</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Fast</span> <span style=''>Proximal</span> <span style=''>Point</span> <span style=''>Method</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Wasserstein</span> <span style=''>Distance</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Wasserstein</span> <span style=''>distance</span> <span style=''>plays</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasingly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>roles</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>programming</span> <span style=''>and</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>Major</span> <span style=''>efforts</span> <span style=''>have</span> <span style=''>been</span> <span style=''>under</span> <span style=''>way</span> <span style=''>to</span> <span style=''>address</span> <span style=''>its</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>some</span> <span style=''>leading</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularized</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variations</span> <span style=''>such</span> <span style=''>as</span> <span style=''>Sinkhorn</span> <span style=''>distance</span> <span style=''>However</span> <span style=''>as</span> <span style=''>we</span> <span style=''>will</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>call</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>of</span> <span style=''>exact</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Wasserstein</span> <span style=''>distance</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularized</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variations</span> <span style=''>with</span> <span style=''>small</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>will</span> <span style=''>fail</span> <span style=''>due</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>numerical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stability</span> <span style=''>issues</span> <span style=''>or</span> <span style=''>degradate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>We</span> <span style=''>address</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developing</span> <span style=''>an</span> <span style=''>Inexact</span> <span style=''>Proximal</span> <span style=''>point</span> <span style=''>method</span> <span style=''>for</span> <span style=''>Optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Transport</span> <span style=''>(IPOT)</span> <span style=''>with</span> <span style=''>the</span> <span style=''>proximal</span> <span style=''>operator</span> <span style='background-color:rg ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3224043715846994);'>Simulated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Annealing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <span style=''>for</span> <span style=''>Graph</span> <span style=''>Coloring</span> <br/><br/><span style=''>The</span> <span style=''>goal</span> <span style=''>of</span> <span style=''>this</span> <span style=''>Random</span> <span style=''>Walks</span> <span style=''>project</span> <span style=''>is</span> <span style=''>to</span> <span style=''>code</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.308411214953271);'>experiment</span> <span style=''>the</span> <span style=''>Markov</span> <span style=''>Chain</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>(MCMC)</span> <span style=''>method</span> <span style=''>for</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>graph</span> <span style=''>coloring</span> <span style=''>In</span> <span style=''>this</span> <span style=''>report</span> <span style=''>we</span> <span style=''>present</span> <span style=''>the</span> <span style=''>plots</span> <span style=''>of</span> <span style=''>cost</span> <span style=''>function</span> <span style=''>(mathbfH)</span> <span style=''>by</span> <span style=''>varying</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>like</span> <span style=''>(mathbfq)</span> <span style=''>(Number</span> <span style=''>of</span> <span style=''>colors</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>in</span> <span style=''>coloring)</span> <span style=''>and</span> <span style=''>(mathbfc)</span> <span style=''>(Average</span> <span style=''>node</span> <span style=''>degree)</span> <span style=''>The</span> <span style=''>results</span> <span style=''>are</span> <span style=''>obtained</span> <span style=''>by</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3224043715846994);'>simulated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>annealing</span> <span style=''>scheme</span> <span style=''>where</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6);'>temperature</span> <span style=''>(inverse</span> <span style=''>of</span> <span style=''>(mathbfbeta))</span> <span style='background-color:rgba(255, 0, 0, 0.32934131736526945);'>parameter</span> <span style=''>in</span> <span style=''>the</span> <span style=''>MCMC</span> <span style=''>is</span> <span style=''>lowered</span> <span style='background-color:rgba(0, 255, 0, 0.5384615384615384);'>progressively</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style=''>k</span> <span style=''>NN</span> <span style=''>search</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Efficient</span> <span style=''>index</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>for</span> <span style=''>fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style=''>nearest</span> <span style=''>neighbor</span> <span style=''>queries</span> <span style=''>are</span> <span style=''>required</span> <span style=''>in</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recommendation</span> <span style=''>systems</span> <span style=''>In</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>spaces</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conventional</span> <span style=''>methods</span> <span style=''>suffer</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>excessive</span> <span style=''>usage</span> <span style=''>of</span> <span style=''>memory</span> <span style=''>and</span> <span style=''>slow</span> <span style=''>response</span> <span style=''>times</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>method</span> <span style=''>where</span> <span style=''>multiple</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projection</span> <span style=''>trees</span> <span style=''>are</span> <span style=''>combined</span> <span style=''>by</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>voting</span> <span style=''>scheme</span> <span style=''>The</span> <span style=''>key</span> <span style=''>idea</span> <span style=''>is</span> <span style=''>to</span> <span style=''>exploit</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>redundancy</span> <span style=''>in</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>candidate</span> <span style=''>sets</span> <span style=''>obtained</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projections</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expensive</span> <span style=''>exact</span> <span style=''>distance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluations</span> <span style=''>The</span> <span style=''>method</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>straightforward</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implement</span> <span style=''>using</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projections</span> <span style=''>which</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>a</span> <span style=''>reduced</span> <span style=''>memory</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>footprint</span> <span style=''>and</span> <span style=''>fast</span> <span style=''>index</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Furthermore</span> <span style=''>it</span> <span style=''>enables</span> <sp ...

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.09038942479456949)
# 	representation (0.1325473383351197)
# 	knowledge (0.1354055019649875)
# 	experimental (0.13933547695605572)
# 	segmentation (0.07324044301536263)
# 	information (0.25509110396570206)
# 	detection (0.12468738835298321)
# 	different (0.26080743122543765)
# 	convolutional (0.13326187924258664)
# 	recognition (0.1382636655948553)
#
# Some Statistics words are:
# 	stochastic (0.1344327836081959)
# 	variables (0.13993003498250875)
# 	theoretical (0.15292353823088456)
# 	algorithm (0.3808095952023988)
# 	estimation (0.1774112943528236)
# 	dimensional (0.16891554222888555)
# 	statistical (0.15892053973013492)
# 	distribution (0.19640179910044978)
# 	inference (0.20889555222388806)
# 	regression (0.18790604697651175)

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="39ca0ff5-f1dd-41dd-a749-d640686495c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("39ca0ff5-f1dd-41dd-a749-d640686495c1")) {                    Plotly.newPlot(                        "39ca0ff5-f1dd-41dd-a749-d640686495c1",                        [{"x":["demonstrate","extension","supervised","constrained","embedding","dimension","introduce","dimensionality","connection","estimation","information","reduction","performance","classifiers","neighbors","intrinsic","classifier","expressions","algorithm","investigate","improvement","satellite","preprocessing","classification","unlabeled","scenarios","techniques","impressive","recovering","extensive","qualitative","unrestricted","pretrained","minimization","positions","advancements","commodity","monocular","estimated","assessment","comparison","generative","calibration","combining","experimental","specifically","displayed","introduction","capitalize","computational","advantage","cumbersome","complexity","augmented","approaches","neighborhood","projection","efficiency","nonlinear","parameters","accelerate","aggressively","bottleneck","communication","assumption","numerical","experiments","convergence","scalability","distributed","gradients","mathematically","googlenet","significant","parallelism","available","situation","probability","expresses","unbalanced","variables","identification","unsupervised","sensibility","association","considering","regression","occurrence","discovery","correlated","discriminant","relationships","assumptions","calculation","inference","remaining","distributions","factorial","political","typically","independence","preferences","probabilistic","processing","particularly","factorizations","principle","preference","smoothness","elections","literature","underlying","predominantly","efficient","structural","accompanied","selection","population","objectives","solutions","discovering","composite","consistently","candidates","tradeoffs","promising","optimization","important","deceptive","mechanism","compensate","particular","combinations","maintains","diversity","transformation","therefore","objective","environment","simultaneously","exploitation","challenging","guarantee","everybody","internally","practically","illustrate","achieving","impossible","protected","contradicting","inferring","similarly","undesired","enforcement","accumulation","additional","diagnosis","hospitals","confronted","challenge","framework","unrelated","virtually","universally","adversarial","automatically","companies","corresponds","generalize","transition","generalizing","unprecedented","applicable","spontaneously","robustness","similarities","parameter","spontaneous","understand","lagrangian","experimentally","correlations","decoupling","explosion","symmetries","described","lipschitz","incidentally","empirically","predictions","orthogonal","efficiently","theoretically","motivated","perturbation","extensions","improving","counterpart","maintained","constraints","convolutional","aggregation","asymptotic","properties","differences","procedure","intricate","theoretical","overlapping","consequences","structures","unexpected","structured","arbitrarily","predictors","distribution","increasingly","additionally","prediction","visualization","interactions","parsimonious","practical","detection","interpretable","predictive","competitively","performing","interaction","selective","according","benchmarks","applications","dimensions","relevance","interpretability","degeneration","supervision","longitudinal","proportion","experiment","predicting","resonance","contrastive","radiological","equivalent","annotated","possessing","generalized","comparing","martingale","multitude","stationarity","situatio ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	confronted
# 	incidentally
# 	disaggregation
# 	unraveling
# 	invertibility
# 	retention
# 	conformity
# 	mechanistic
# 	neuroscientists
# 	laplacians
# 	bonferroni
# 	normalizer
# 	subexponential
# 	fluctuation
# 	concordance
# 	transferability
# 	penalizations
# 	unveiling
# 	martingales
# 	quantiles
# Some words which never appear in Statistics papers:
# 	monocular
# 	googlenet
# 	predominantly
# 	deceptive
# 	operative
# 	deformation
# 	autonomously
# 	allocated
# 	transcriptions
# 	notations
# 	appearances
# 	counterfactuals
# 	harnessing
# 	profitable
# 	conjunctions
# 	dermoscopy
# 	knowledges
# 	pathologists
# 	cityscapes
# 	radiologists

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0708758137820905e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7575
